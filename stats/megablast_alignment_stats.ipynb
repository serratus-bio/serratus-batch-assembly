# %% [markdown]
# ### examines catA-v3 versus nt megablast alignments

# %%
from collections import defaultdict
import gzip
import subprocess
import statistics

import seaborn as sns
import pandas as pd
import matplotlib.pylab as plt

# %%
fh = gzip.open("catA-v3.megablast-nt-fmt6.gz")

from blast import parse

buffer = ""
def print_later(*args):
    s = " ".join(map(str,args))
    global buffer
    buffer += s + "\n"
    
def get_ref_length(ref_name):
    cmd = ["/home/ec2-user/ncbi-blast-2.10.1+/bin/blastdbcmd", "-db","/home/ec2-user/blastdb/nt","-entry",ref_name,"-outfmt","%l"]
    return int(subprocess.check_output(cmd))

df = pd.DataFrame(columns=['Assembly', 'AssemblyLen', 'Tech', 'BestRef','BestRefLen', 'LongestHit', 'QueryCov','RefCov', 'QueryDup', 'RefDup', 'IDYmean', 'IDYstdev'])

tech = dict(map(lambda x:x.split(),open("catA-v3.tech.txt").read().strip().split('\n')))

# loop over assemblies
for blast_record in parse(fh):
    #print('query id: {}'.format(blast_record.qid))
    query = blast_record.qid.decode()
    accession = query.split('.')[0]
    query_length = int(query.split("_")[3])
    ref_length = None
    best_ref = None
    query_cov_array = [0] * query_length
    ref_cov_array = None
    buffer = ""
    identities = []
    nb_alns_best_ref = 0
    longest_aln_length = 0
    
    # parse alignments between this assembly and nt
    for hit in blast_record.hits:
        for hsp in hit:
            if best_ref is None:
                # set the only reference we'll ever look at (the best one), discarding any other reference in further hsp
                best_ref = hsp.sid
                ref_length = get_ref_length(best_ref) 
                ref_cov_array = [0] * ref_length
            else:
                if hsp.sid != best_ref:
                    continue
                    
            nb_alns_best_ref += 1
            longest_aln_length = max(longest_aln_length, hsp.length)
            
            print_later('****Alignment****')
            print_later('aligns_to:', hsp.sid)
            print_later('aln_length:', hsp.length, '/', query_length)
            print_later('e value:', hsp.evalue)
            
            if hsp.pident < 90 and hsp.length > 1000:
                print("!",query,hsp.pident,hsp.length)
            
            # record which positions of the query (=assembly) are covered by an alignment to the best reference
            assert(hsp.qstart < hsp.qend)
            for i in range(hsp.qstart, hsp.qend): 
                query_cov_array[i] += 1
                
            # do same for positions of the reference
            if hsp.sstart > hsp.send:
                hsp.sstart, hsp.send =  hsp.send, hsp.sstart
            for i in range(hsp.sstart, hsp.send): 
                ref_cov_array[i] += 1
                
            identities += [hsp.pident]
            
    idy_stdev = 0 if len(identities) < 2 else statistics.stdev(identities)
    
    # determine assemblies where < 95% of the bases are covered by an alignment
    query_cov = sum([1 for x in query_cov_array if x >= 1]) / query_length
    ref_cov = sum([1 for x in ref_cov_array if x >= 1]) / ref_length
    query_dup = sum([0] + [x-1 for x in query_cov_array if x >= 2]) 
    ref_dup = sum([0] + [x-1 for x in ref_cov_array if x >= 2]) 
    if query_cov < 0.95  \
    or ref_cov   < 0.95 \
    or query_dup > 200 \
    or ref_dup > 200 \
    or longest_aln_length < query_length * 2/3:
        print("suspicious assembly (%.2f query coverage, %.2f ref coverage, %d query dup, %d ref dup, longest hit %d):" % (query_cov, ref_cov, query_dup, ref_dup, longest_aln_length) ,query)
        print(buffer)
        
        # insert into dataframe
        df.loc[-1] = [accession, query_length, tech[accession], best_ref, ref_length, longest_aln_length, query_cov, ref_cov, query_dup, ref_dup, statistics.mean(identities), idy_stdev]
        df.index = df.index + 1
        df = df.sort_index() 
    #break
   
fh.close()
# Out:
# suspicious assembly (0.93 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 30094): SRR1191915.coronaspades.NODE_1_length_32532_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 30094 / 32532
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 8 query dup, 1206 ref dup, longest hit 29911): SRR11140749.coronaspades.NODE_1_length_31251_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT121215.1
# aln_length: 29911 / 31251
# e value: 0.0
# ****Alignment****
# aligns_to: MT121215.1
# aln_length: 480 / 31251
# e value: 0.0
# ****Alignment****
# aligns_to: MT121215.1
# aln_length: 272 / 31251
# e value: 5.71e-123
# ****Alignment****
# aligns_to: MT121215.1
# aln_length: 252 / 31251
# e value: 3.49e-110
# ****Alignment****
# aligns_to: MT121215.1
# aln_length: 227 / 31251
# e value: 7.6e-102
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25210): SRR11494506.coronaspades.NODE_1_length_25214_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 25210 / 25214
# e value: 0.0
#
# suspicious assembly (0.99 query coverage, 0.05 ref coverage, 0 query dup, 30168 ref dup, longest hit 1479): ERR4164903.coronaspades.NODE_3_length_32040_cluster_3_candidate_1_domains_43
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1479 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 1467 / 32040
# e value: 0.0
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 350 / 32040
# e value: 1.16e-179
# ****Alignment****
# aligns_to: MT520274.1
# aln_length: 287 / 32040
# e value: 2.75e-116
#
# suspicious assembly (1.00 query coverage, 0.89 ref coverage, 6 query dup, 74 ref dup, longest hit 26716): SRR11916011.coronaspades.NODE_1_length_26805_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 26716 / 26805
# e value: 0.0
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 76 / 26805
# e value: 3.37e-25
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 14 query dup, 259 ref dup, longest hit 29854): SRR12003638.coronaspades.NODE_1_length_30104_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT535488.1
# aln_length: 29854 / 30104
# e value: 0.0
# ****Alignment****
# aligns_to: MT535488.1
# aln_length: 123 / 30104
# e value: 1.69e-53
# ****Alignment****
# aligns_to: MT535488.1
# aln_length: 107 / 30104
# e value: 6.16e-43
# ****Alignment****
# aligns_to: MT535488.1
# aln_length: 32 / 30104
# e value: 0.007
#
# suspicious assembly (1.00 query coverage, 0.90 ref coverage, 4 query dup, 125 ref dup, longest hit 26881): ERR4182440.coronaspades.NODE_1_length_26986_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 26881 / 26986
# e value: 0.0
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 126 / 26986
# e value: 3.26e-55
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25229): SRR11597148.coronaspades.NODE_1_length_25229_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: MT259230.1
# aln_length: 25229 / 25229
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.99 ref coverage, 1 query dup, 231 ref dup, longest hit 29683): SRR11939551.coronaspades.NODE_1_length_29914_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 29683 / 29914
# e value: 0.0
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 126 / 29914
# e value: 3.61e-55
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 107 / 29914
# e value: 1.32e-44
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 40 query dup, 313 ref dup, longest hit 26015): SRR6713743.coronaspades.NODE_1_length_28153_cluster_1_candidate_1_domains_40
# ****Alignment****
# aligns_to: KJ645704.1
# aln_length: 26015 / 28153
# e value: 0.0
# ****Alignment****
# aligns_to: KJ645704.1
# aln_length: 1838 / 28153
# e value: 0.0
# ****Alignment****
# aligns_to: KJ645704.1
# aln_length: 153 / 28153
# e value: 1.56e-63
# ****Alignment****
# aligns_to: KJ645704.1
# aln_length: 72 / 28153
# e value: 3.54e-25
# ****Alignment****
# aligns_to: KJ645704.1
# aln_length: 50 / 28153
# e value: 2.8e-11
# ****Alignment****
# aligns_to: KJ645704.1
# aln_length: 42 / 28153
# e value: 7.83e-07
#
# suspicious assembly (1.00 query coverage, 0.90 ref coverage, 8 query dup, 122 ref dup, longest hit 25068): SRR1033849.coronaspades.NODE_1_length_25183_cluster_1_candidate_1_domains_27
# ****Alignment****
# aligns_to: EU418976.1
# aln_length: 25068 / 25183
# e value: 0.0
# ****Alignment****
# aligns_to: EU418976.1
# aln_length: 123 / 25183
# e value: 3.99e-44
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 0 query dup, 223 ref dup, longest hit 29835): SRR11597213.coronaspades.NODE_1_length_30136_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 29835 / 30136
# e value: 0.0
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 224 / 30136
# e value: 5.79e-88
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 14 query dup, 546 ref dup, longest hit 29809): ERR4182437.coronaspades.NODE_1_length_30333_cluster_1_candidate_1_domains_42
# ****Alignment****
# aligns_to: MT627422.1
# aln_length: 29809 / 30333
# e value: 0.0
# ****Alignment****
# aligns_to: MT627422.1
# aln_length: 461 / 30333
# e value: 0.0
# ****Alignment****
# aligns_to: MT627422.1
# aln_length: 100 / 30333
# e value: 8.09e-37
#
# suspicious assembly (1.00 query coverage, 0.95 ref coverage, 0 query dup, 0 ref dup, longest hit 28295): SRR11968904.coronaspades.NODE_1_length_28295_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: MT568634.1
# aln_length: 28295 / 28295
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.88 ref coverage, 0 query dup, 0 ref dup, longest hit 26287): SRR11622083.coronaspades.NODE_1_length_26308_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 26287 / 26308
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.89 ref coverage, 0 query dup, 0 ref dup, longest hit 26400): SRR11857956.coronaspades.NODE_1_length_26400_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: MT558673.1
# aln_length: 26400 / 26400
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 304 query dup, 303 ref dup, longest hit 28378): ERR2738384.coronaspades.NODE_1_length_28445_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: MH687966.1
# aln_length: 28378 / 28445
# e value: 0.0
# ****Alignment****
# aligns_to: MH687966.1
# aln_length: 150 / 28445
# e value: 1.56e-68
# ****Alignment****
# aligns_to: MH687966.1
# aln_length: 156 / 28445
# e value: 3.46e-50
#
# suspicious assembly (1.00 query coverage, 0.99 ref coverage, 5 query dup, 217 ref dup, longest hit 28067): ERR1301491.coronaspades.NODE_1_length_28279_cluster_1_candidate_1_domains_33
# ****Alignment****
# aligns_to: MH687944.1
# aln_length: 28067 / 28279
# e value: 0.0
# ****Alignment****
# aligns_to: MH687944.1
# aln_length: 123 / 28279
# e value: 1.59e-53
# ****Alignment****
# aligns_to: MH687944.1
# aln_length: 96 / 28279
# e value: 7.54e-37
#
# suspicious assembly (1.00 query coverage, 0.85 ref coverage, 0 query dup, 0 ref dup, longest hit 25431): SRR11826984.coronaspades.NODE_1_length_25450_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: MT520215.1
# aln_length: 25431 / 25450
# e value: 0.0
# suspicious assembly (1.00 query coverage, 0.94 ref coverage, 0 query dup, 0 ref dup, longest hit 27986): SRR11578301.coronaspades.NODE_1_length_27986_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 27986 / 27986
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 8 query dup, 163 ref dup, longest hit 15955): SRR11621817.coronaspades.NODE_1_length_29932_cluster_1_candidate_1_domains_39
# ****Alignment****
# aligns_to: MT627434.1
# aln_length: 15955 / 29932
# e value: 0.0
# ****Alignment****
# aligns_to: MT627434.1
# aln_length: 13797 / 29932
# e value: 0.0
# ****Alignment****
# aligns_to: MT627434.1
# aln_length: 109 / 29932
# e value: 1.02e-45
# ****Alignment****
# aligns_to: MT627434.1
# aln_length: 34 / 29932
# e value: 0.000501
# ****Alignment****
# aligns_to: MT627434.1
# aln_length: 31 / 29932
# e value: 0.023
#
# suspicious assembly (1.00 query coverage, 0.90 ref coverage, 0 query dup, 0 ref dup, longest hit 25212): SRR10829954.coronaspades.NODE_1_length_25269_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: KY420075.1
# aln_length: 25212 / 25269
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 3 query dup, 82 ref dup, longest hit 16001): SRR6893872.coronaspades.NODE_1_length_25471_cluster_1_candidate_1_domains_23
# ****Alignment****
# aligns_to: KY364365.1
# aln_length: 16001 / 25471
# e value: 0.0
# ****Alignment****
# aligns_to: KY364365.1
# aln_length: 9474 / 25471
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.87 ref coverage, 0 query dup, 0 ref dup, longest hit 25824): SRR11621903.coronaspades.NODE_1_length_25821_cluster_1_candidate_1_domains_40
# ****Alignment****
# aligns_to: MT520215.1
# aln_length: 25824 / 25821
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 115 query dup, 252 ref dup, longest hit 29884): SRR11393704.coronaspades.NODE_1_length_30190_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 29884 / 30190
# e value: 0.0
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 125 / 30190
# e value: 1.31e-54
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 129 / 30190
# e value: 1.69e-53
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 115 / 30190
# e value: 7.94e-47
#
# suspicious assembly (0.93 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 30098): SRR1192073.coronaspades.NODE_1_length_32442_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 30098 / 32442
# e value: 0.0
#
# suspicious assembly (0.79 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 30256): SRR10915173.coronaspades.NODE_1_length_38489_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: KJ473822.1
# aln_length: 30256 / 38489
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 66 query dup, 201 ref dup, longest hit 27982): SRR6713893.coronaspades.NODE_1_length_28113_cluster_1_candidate_1_domains_41
# ****Alignment****
# aligns_to: KJ645691.1
# aln_length: 27982 / 28113
# e value: 0.0
# ****Alignment****
# aligns_to: KJ645691.1
# aln_length: 131 / 28113
# e value: 3.54e-25
# ****Alignment****
# aligns_to: KJ645691.1
# aln_length: 72 / 28113
# e value: 3.54e-25
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25217): SRR11494532.coronaspades.NODE_1_length_25237_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 25217 / 25237
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.93 ref coverage, 0 query dup, 71 ref dup, longest hit 28042): ERR963027.coronaspades.NODE_1_length_28162_cluster_1_candidate_1_domains_30
# ****Alignment****
# aligns_to: KJ813439.1
# aln_length: 28042 / 28162
# e value: 0.0
# ****Alignment****
# aligns_to: KJ813439.1
# aln_length: 72 / 28162
# e value: 5.93e-23
#
# ! SRR10873981.coronaspades.NODE_1_length_26508_cluster_1_candidate_1_domains_25 78.892 14582
# suspicious assembly (0.60 query coverage, 0.60 ref coverage, 0 query dup, 0 ref dup, longest hit 14582): SRR10873981.coronaspades.NODE_1_length_26508_cluster_1_candidate_1_domains_25
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 14582 / 26508
# e value: 0.0
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 665 / 26508
# e value: 2.94e-115
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 305 / 26508
# e value: 3.83e-109
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 479 / 26508
# e value: 1.16e-49
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 73 / 26508
# e value: 9.41e-16
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 3 query dup, 82 ref dup, longest hit 15970): SRR7623978.coronaspades.NODE_1_length_25432_cluster_1_candidate_1_domains_23
# ****Alignment****
# aligns_to: KY364365.1
# aln_length: 15970 / 25432
# e value: 0.0
# ****Alignment****
# aligns_to: KY364365.1
# aln_length: 9466 / 25432
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 3 query dup, 58 ref dup, longest hit 25217): SRR11494725.coronaspades.NODE_1_length_25279_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: MT520521.1
# aln_length: 25217 / 25279
# e value: 0.0
# ****Alignment****
# aligns_to: MT520521.1
# aln_length: 67 / 25279
# e value: 1.92e-22
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 273 query dup, 333 ref dup, longest hit 29937): ERR4181748.coronaspades.NODE_1_length_30021_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT079845.1
# aln_length: 29937 / 30021
# e value: 0.0
# ****Alignment****
# aligns_to: MT079845.1
# aln_length: 134 / 30021
# e value: 2.8e-56
# ****Alignment****
# aligns_to: MT079845.1
# aln_length: 139 / 30021
# e value: 1.32e-44
# ****Alignment****
# aligns_to: MT079845.1
# aln_length: 54 / 30021
# e value: 3.83e-15
# ****Alignment****
# aligns_to: MT079845.1
# aln_length: 35 / 30021
# e value: 1.1
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 69 query dup, 206 ref dup, longest hit 27964): SRR6713880.coronaspades.NODE_1_length_28097_cluster_1_candidate_1_domains_40
# ****Alignment****
# aligns_to: KJ645704.1
# aln_length: 27964 / 28097
# e value: 0.0
# ****Alignment****
# aligns_to: KJ645704.1
# aln_length: 77 / 28097
# e value: 2.73e-26
# ****Alignment****
# aligns_to: KJ645704.1
# aln_length: 131 / 28097
# e value: 3.54e-25
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 0 query dup, 1906 ref dup, longest hit 17094): SRR7623977.coronaspades.NODE_1_length_27342_cluster_1_candidate_1_domains_26
# ****Alignment****
# aligns_to: KY364365.1
# aln_length: 17094 / 27342
# e value: 0.0
# ****Alignment****
# aligns_to: KY364365.1
# aln_length: 10217 / 27342
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 1 query dup, 502 ref dup, longest hit 29863): ERR4182427.coronaspades.NODE_1_length_30352_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: MT374105.1
# aln_length: 29863 / 30352
# e value: 0.0
# ****Alignment****
# aligns_to: MT374105.1
# aln_length: 261 / 30352
# e value: 1.55e-118
# ****Alignment****
# aligns_to: MT374105.1
# aln_length: 245 / 30352
# e value: 1.58e-108
#
# suspicious assembly (1.00 query coverage, 0.89 ref coverage, 183 query dup, 45 ref dup, longest hit 26516): SRR5872097.coronaspades.NODE_1_length_26518_cluster_1_candidate_1_domains_28
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 26516 / 26518
# e value: 0.0
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 46 / 26518
# e value: 9.48e-11
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 44 / 26518
# e value: 1.23e-09
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 34 / 26518
# e value: 0.000444
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 33 / 26518
# e value: 0.002
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 31 / 26518
# e value: 0.021
#
# suspicious assembly (1.00 query coverage, 0.85 ref coverage, 0 query dup, 0 ref dup, longest hit 26181): SRR6425313.coronaspades.NODE_1_length_26182_cluster_1_candidate_1_domains_31
# ****Alignment****
# aligns_to: KY994645.1
# aln_length: 26181 / 26182
# e value: 0.0
#
# suspicious assembly (0.73 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 18940): SRR7239363.coronaspades.NODE_1_length_26091_cluster_1_candidate_1_domains_24
# ****Alignment****
# aligns_to: MT025058.1
# aln_length: 18940 / 26091
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 304 query dup, 303 ref dup, longest hit 28378): ERR3179763.coronaspades.NODE_1_length_28445_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: MH687966.1
# aln_length: 28378 / 28445
# e value: 0.0
# ****Alignment****
# aligns_to: MH687966.1
# aln_length: 150 / 28445
# e value: 1.56e-68
# ****Alignment****
# aligns_to: MH687966.1
# aln_length: 156 / 28445
# e value: 3.46e-50
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 10 query dup, 245 ref dup, longest hit 29872): SRR11140748.coronaspades.NODE_1_length_30108_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT039887.1
# aln_length: 29872 / 30108
# e value: 0.0
# ****Alignment****
# aligns_to: MT039887.1
# aln_length: 122 / 30108
# e value: 6.08e-53
# ****Alignment****
# aligns_to: MT039887.1
# aln_length: 125 / 30108
# e value: 6.08e-53
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 63 query dup, 201 ref dup, longest hit 27986): SRR6713902.coronaspades.NODE_1_length_28120_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: KR265814.1
# aln_length: 27986 / 28120
# e value: 0.0
# ****Alignment****
# aligns_to: KR265814.1
# aln_length: 131 / 28120
# e value: 1.65e-23
# ****Alignment****
# aligns_to: KR265814.1
# aln_length: 72 / 28120
# e value: 1.65e-23
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 6 query dup, 330 ref dup, longest hit 28021): ERR3013343.coronaspades.NODE_1_length_28355_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: LT898439.1
# aln_length: 28021 / 28355
# e value: 0.0
# ****Alignment****
# aligns_to: LT898439.1
# aln_length: 127 / 28355
# e value: 9.51e-56
# ****Alignment****
# aligns_to: LT898439.1
# aln_length: 136 / 28355
# e value: 4.42e-54
# ****Alignment****
# aligns_to: LT898439.1
# aln_length: 70 / 28355
# e value: 9.99e-21
#
# suspicious assembly (0.91 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 30098): SRR1190466.coronaspades.NODE_1_length_33133_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 30098 / 33133
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.89 ref coverage, 0 query dup, 178 ref dup, longest hit 26582): ERR4164805.coronaspades.NODE_1_length_26748_cluster_1_candidate_1_domains_34
# ****Alignment****
# aligns_to: MT627422.1
# aln_length: 26582 / 26748
# e value: 0.0
# ****Alignment****
# aligns_to: MT627422.1
# aln_length: 181 / 26748
# e value: 6.7e-82
#
# suspicious assembly (0.94 query coverage, 1.00 ref coverage, 0 query dup, 47 ref dup, longest hit 30101): SRR1190467.coronaspades.NODE_1_length_32181_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 30101 / 32181
# e value: 0.0
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 48 / 32181
# e value: 8.89e-12
#
# suspicious assembly (1.00 query coverage, 0.91 ref coverage, 0 query dup, 0 ref dup, longest hit 27110): SRR11857972.coronaspades.NODE_1_length_27110_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 27110 / 27110
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.89 ref coverage, 331 query dup, 90 ref dup, longest hit 23419): SRR8189298.coronaspades.NODE_1_length_25031_cluster_1_candidate_1_domains_23
# ****Alignment****
# aligns_to: MK204411.1
# aln_length: 23419 / 25031
# e value: 0.0
# ****Alignment****
# aligns_to: MK204411.1
# aln_length: 1490 / 25031
# e value: 0.0
# ****Alignment****
# aligns_to: MK204411.1
# aln_length: 92 / 25031
# e value: 1.46e-28
# ****Alignment****
# aligns_to: MK204411.1
# aln_length: 92 / 25031
# e value: 3.15e-25
# ****Alignment****
# aligns_to: MK204411.1
# aln_length: 92 / 25031
# e value: 5.27e-23
# ****Alignment****
# aligns_to: MK204411.1
# aln_length: 77 / 25031
# e value: 5.31e-18
# ****Alignment****
# aligns_to: MK204411.1
# aln_length: 74 / 25031
# e value: 6.87e-17
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 3 query dup, 241 ref dup, longest hit 29875): SRR11140746.coronaspades.NODE_1_length_30137_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT039887.1
# aln_length: 29875 / 30137
# e value: 0.0
# ****Alignment****
# aligns_to: MT039887.1
# aln_length: 122 / 30137
# e value: 6.08e-53
# ****Alignment****
# aligns_to: MT039887.1
# aln_length: 121 / 30137
# e value: 2.19e-52
#
# suspicious assembly (1.00 query coverage, 0.90 ref coverage, 1616 query dup, 1306 ref dup, longest hit 26528): SRR8369129.coronaspades.NODE_1_length_26534_cluster_1_candidate_1_domains_29
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 26528 / 26534
# e value: 0.0
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 133 / 26534
# e value: 5.39e-48
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 119 / 26534
# e value: 3.27e-40
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 89 / 26534
# e value: 1.55e-23
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 72 / 26534
# e value: 9.42e-16
# ****Alignment****
# aligns_to: DQ415911.1
# aln_length: 59 / 26534
# e value: 1.59e-08
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 121 ref dup, longest hit 25036): SRR11593358.coronaspades.NODE_1_length_25158_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 25036 / 25158
# e value: 0.0
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 122 / 25158
# e value: 5.08e-53
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25220): SRR11494750.coronaspades.NODE_1_length_25220_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 25220 / 25220
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 0 query dup, 242 ref dup, longest hit 29861): SRR11593359.coronaspades.NODE_1_length_30105_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT358641.1
# aln_length: 29861 / 30105
# e value: 0.0
# ****Alignment****
# aligns_to: MT358641.1
# aln_length: 122 / 30105
# e value: 6.08e-53
# ****Alignment****
# aligns_to: MT358641.1
# aln_length: 122 / 30105
# e value: 6.08e-53
#
# ! SRR10873977.coronaspades.NODE_1_length_26576_cluster_1_candidate_1_domains_25 78.89 14581
# suspicious assembly (0.60 query coverage, 0.60 ref coverage, 31 query dup, 61 ref dup, longest hit 14581): SRR10873977.coronaspades.NODE_1_length_26576_cluster_1_candidate_1_domains_25
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 14581 / 26576
# e value: 0.0
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 665 / 26576
# e value: 2.95e-115
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 305 / 26576
# e value: 3.84e-109
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 479 / 26576
# e value: 1.16e-49
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 73 / 26576
# e value: 9.37e-21
# ****Alignment****
# aligns_to: FJ376622.1
# aln_length: 62 / 26576
# e value: 2.64e-11
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 62 query dup, 201 ref dup, longest hit 27986): SRR6713905.coronaspades.NODE_1_length_28123_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: KR265814.1
# aln_length: 27986 / 28123
# e value: 0.0
# ****Alignment****
# aligns_to: KR265814.1
# aln_length: 72 / 28123
# e value: 3.54e-25
# ****Alignment****
# aligns_to: KR265814.1
# aln_length: 131 / 28123
# e value: 1.65e-23
#
# suspicious assembly (0.92 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 29709): SRR11550039.coronaspades.NODE_1_length_32184_cluster_1_candidate_1_domains_44
# ****Alignment****
# aligns_to: FJ429166.1
# aln_length: 29709 / 32184
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.90 ref coverage, 7 query dup, 32 ref dup, longest hit 26752): SRR11859139.coronaspades.NODE_1_length_26806_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT614525.1
# aln_length: 26752 / 26806
# e value: 0.0
# ****Alignment****
# aligns_to: MT614525.1
# aln_length: 62 / 26806
# e value: 1.22e-19
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 1 query dup, 291 ref dup, longest hit 24131): ERR4182443.coronaspades.NODE_1_length_30141_cluster_1_candidate_1_domains_41
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 24131 / 30141
# e value: 0.0
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 6031 / 30141
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.85 ref coverage, 2 query dup, 71 ref dup, longest hit 25206): SRR11494457.coronaspades.NODE_1_length_25301_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: MT451603.1
# aln_length: 25206 / 25301
# e value: 0.0
# ****Alignment****
# aligns_to: MT451603.1
# aln_length: 72 / 25301
# e value: 3.18e-25
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 62 query dup, 207 ref dup, longest hit 27988): SRR6713767.coronaspades.NODE_1_length_28129_cluster_1_candidate_1_domains_40
# ****Alignment****
# aligns_to: KF650373.1
# aln_length: 27988 / 28129
# e value: 0.0
# ****Alignment****
# aligns_to: KF650373.1
# aln_length: 137 / 28129
# e value: 7.61e-27
# ****Alignment****
# aligns_to: KF650373.1
# aln_length: 72 / 28129
# e value: 3.54e-25
#
# suspicious assembly (1.00 query coverage, 0.88 ref coverage, 0 query dup, 0 ref dup, longest hit 26412): ERR4181768.coronaspades.NODE_1_length_26418_cluster_1_candidate_1_domains_34
# ****Alignment****
# aligns_to: MT325599.1
# aln_length: 26412 / 26418
# e value: 0.0
#
# suspicious assembly (0.99 query coverage, 1.00 ref coverage, 0 query dup, 207 ref dup, longest hit 30995): SRR9430938.coronaspades.NODE_1_length_31509_cluster_1_candidate_1_domains_33
# ****Alignment****
# aligns_to: FJ425188.1
# aln_length: 30995 / 31509
# e value: 0.0
# ****Alignment****
# aligns_to: FJ425188.1
# aln_length: 209 / 31509
# e value: 7.94e-77
#
# suspicious assembly (1.00 query coverage, 0.99 ref coverage, 6 query dup, 625 ref dup, longest hit 29692): ERR4182439.coronaspades.NODE_1_length_30298_cluster_1_candidate_1_domains_47
# ****Alignment****
# aligns_to: MT535497.1
# aln_length: 29692 / 30298
# e value: 0.0
# ****Alignment****
# aligns_to: MT535497.1
# aln_length: 402 / 30298
# e value: 0.0
# ****Alignment****
# aligns_to: MT535497.1
# aln_length: 201 / 30298
# e value: 4.56e-79
# ****Alignment****
# aligns_to: MT535497.1
# aln_length: 29 / 30298
# e value: 0.31
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25213): SRR11494528.coronaspades.NODE_1_length_25213_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 25213 / 25213
# e value: 0.0
#
# suspicious assembly (0.88 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 30099): SRR1193955.coronaspades.NODE_1_length_34150_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 30099 / 34150
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 0 query dup, 457 ref dup, longest hit 29838): ERR4182432.coronaspades.NODE_1_length_30345_cluster_1_candidate_1_domains_41
# ****Alignment****
# aligns_to: MT520546.1
# aln_length: 29838 / 30345
# e value: 0.0
# ****Alignment****
# aligns_to: MT520546.1
# aln_length: 459 / 30345
# e value: 6.73e-167
#
# suspicious assembly (0.99 query coverage, 1.00 ref coverage, 1 query dup, 436 ref dup, longest hit 29820): ERR4164796.coronaspades.NODE_1_length_30423_cluster_1_candidate_1_domains_39
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 29820 / 30423
# e value: 0.0
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 228 / 30423
# e value: 1.24e-99
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 210 / 30423
# e value: 7.51e-92
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25216): SRR11578204.coronaspades.NODE_1_length_25216_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 25216 / 25216
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.94 ref coverage, 0 query dup, 0 ref dup, longest hit 29326): ERR3179284.coronaspades.NODE_1_length_29326_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: MH687972.1
# aln_length: 29326 / 29326
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.94 ref coverage, 113 query dup, 0 ref dup, longest hit 28016): SRR11777735.coronaspades.NODE_1_length_28047_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 28016 / 28047
# e value: 0.0
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 115 / 28047
# e value: 7.38e-47
#
# suspicious assembly (1.00 query coverage, 0.91 ref coverage, 0 query dup, 251 ref dup, longest hit 27293): ERR4182183.coronaspades.NODE_1_length_27534_cluster_1_candidate_1_domains_39
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 27293 / 27534
# e value: 0.0
# ****Alignment****
# aligns_to: MT628262.1
# aln_length: 256 / 27534
# e value: 1.45e-98
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25217): SRR11578190.coronaspades.NODE_1_length_25234_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: MT470114.1
# aln_length: 25217 / 25234
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25216): SRR11494499.coronaspades.NODE_1_length_25216_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: MT520215.1
# aln_length: 25216 / 25216
# e value: 0.0
#
# suspicious assembly (0.90 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 29701): SRR1195366.coronaspades.NODE_1_length_32879_cluster_1_candidate_1_domains_41
# ****Alignment****
# aligns_to: AY278741.1
# aln_length: 29701 / 32879
# e value: 0.0
#
# suspicious assembly (0.95 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 29720): SRR1030193.coronaspades.NODE_1_length_31374_cluster_1_candidate_1_domains_47
# ****Alignment****
# aligns_to: FJ882957.1
# aln_length: 29720 / 31374
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 153 query dup, 287 ref dup, longest hit 27959): SRR6713741.coronaspades.NODE_1_length_28070_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: KJ645665.1
# aln_length: 27959 / 28070
# e value: 0.0
# ****Alignment****
# aligns_to: KJ645665.1
# aln_length: 121 / 28070
# e value: 9.55e-46
# ****Alignment****
# aligns_to: KJ645665.1
# aln_length: 97 / 28070
# e value: 2.11e-27
# ****Alignment****
# aligns_to: KJ645665.1
# aln_length: 72 / 28070
# e value: 3.53e-25
#
# suspicious assembly (1.00 query coverage, 0.99 ref coverage, 3 query dup, 89 ref dup, longest hit 15246): ERR4181727.coronaspades.NODE_1_length_29749_cluster_1_candidate_1_domains_42
# ****Alignment****
# aligns_to: MT428554.1
# aln_length: 15246 / 29749
# e value: 0.0
# ****Alignment****
# aligns_to: MT428554.1
# aln_length: 14507 / 29749
# e value: 0.0
#
# suspicious assembly (0.91 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 29702): SRR1195790.coronaspades.NODE_1_length_32562_cluster_1_candidate_1_domains_42
# ****Alignment****
# aligns_to: AY278741.1
# aln_length: 29702 / 32562
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 63 query dup, 201 ref dup, longest hit 27979): SRR6713776.coronaspades.NODE_1_length_28113_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MK071627.1
# aln_length: 27979 / 28113
# e value: 0.0
# ****Alignment****
# aligns_to: MK071627.1
# aln_length: 131 / 28113
# e value: 3.54e-25
# ****Alignment****
# aligns_to: MK071627.1
# aln_length: 72 / 28113
# e value: 3.54e-25
#
# suspicious assembly (0.99 query coverage, 0.99 ref coverage, 1 query dup, 593 ref dup, longest hit 21157): ERR4182199.coronaspades.NODE_1_length_30660_cluster_1_candidate_1_domains_44
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 21157 / 30660
# e value: 0.0
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 8554 / 30660
# e value: 0.0
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 375 / 30660
# e value: 1.44e-178
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 126 / 30660
# e value: 3.7e-55
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 99 / 30660
# e value: 2.94e-36
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 62 query dup, 201 ref dup, longest hit 27982): SRR6713714.coronaspades.NODE_1_length_28120_cluster_1_candidate_1_domains_42
# ****Alignment****
# aligns_to: KU982977.1
# aln_length: 27982 / 28120
# e value: 0.0
# ****Alignment****
# aligns_to: KU982977.1
# aln_length: 131 / 28120
# e value: 3.54e-25
# ****Alignment****
# aligns_to: KU982977.1
# aln_length: 72 / 28120
# e value: 3.54e-25
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 0 query dup, 1057 ref dup, longest hit 29808): ERR4164797.coronaspades.NODE_1_length_30903_cluster_1_candidate_1_domains_39
# ****Alignment****
# aligns_to: MT627422.1
# aln_length: 29808 / 30903
# e value: 0.0
# ****Alignment****
# aligns_to: MT627422.1
# aln_length: 1109 / 30903
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.90 ref coverage, 337 query dup, 115 ref dup, longest hit 26486): ERR1424897.coronaspades.NODE_1_length_26516_cluster_1_candidate_1_domains_29
# ****Alignment****
# aligns_to: KF686344.1
# aln_length: 26486 / 26516
# e value: 0.0
# ****Alignment****
# aligns_to: KF686344.1
# aln_length: 54 / 26516
# e value: 1.58e-13
# ****Alignment****
# aligns_to: KF686344.1
# aln_length: 54 / 26516
# e value: 1.58e-13
# ****Alignment****
# aligns_to: KF686344.1
# aln_length: 54 / 26516
# e value: 1.58e-13
# ****Alignment****
# aligns_to: KF686344.1
# aln_length: 54 / 26516
# e value: 1.58e-13
# ****Alignment****
# aligns_to: KF686344.1
# aln_length: 54 / 26516
# e value: 1.58e-13
# ****Alignment****
# aligns_to: KF686344.1
# aln_length: 41 / 26516
# e value: 2.65e-06
# ****Alignment****
# aligns_to: KF686344.1
# aln_length: 33 / 26516
# e value: 0.002
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 0 query dup, 1165 ref dup, longest hit 22387): SRR11772243.coronaspades.NODE_1_length_30990_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT450890.1
# aln_length: 22387 / 30990
# e value: 0.0
# ****Alignment****
# aligns_to: MT450890.1
# aln_length: 8600 / 30990
# e value: 0.0
#
# suspicious assembly (0.92 query coverage, 1.00 ref coverage, 0 query dup, 47 ref dup, longest hit 29713): SRR1030058.coronaspades.NODE_1_length_32413_cluster_1_candidate_1_domains_47
# ****Alignment****
# aligns_to: FJ882957.1
# aln_length: 29713 / 32413
# e value: 0.0
# ****Alignment****
# aligns_to: FJ882957.1
# aln_length: 48 / 32413
# e value: 8.96e-12
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 0 query dup, 12 ref dup, longest hit 19372): SRR11771957.coronaspades.NODE_1_length_29877_cluster_1_candidate_1_domains_46
# ****Alignment****
# aligns_to: MT482127.1
# aln_length: 19372 / 29877
# e value: 0.0
# ****Alignment****
# aligns_to: MT482127.1
# aln_length: 10498 / 29877
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.99 ref coverage, 4 query dup, 2259 ref dup, longest hit 29520): ERR4164855.coronaspades.NODE_1_length_31837_cluster_1_candidate_1_domains_49
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 29520 / 31837
# e value: 0.0
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 1245 / 31837
# e value: 0.0
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 998 / 31837
# e value: 0.0
# ****Alignment****
# aligns_to: MT627426.1
# aln_length: 199 / 31837
# e value: 6.16e-83
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 440 query dup, 461 ref dup, longest hit 31232): ERR1301554.coronaspades.NODE_1_length_31380_cluster_1_candidate_1_domains_31
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 31232 / 31380
# e value: 0.0
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 145 / 31380
# e value: 6.56e-28
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 70 / 31380
# e value: 5.11e-24
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 60 / 31380
# e value: 1.85e-18
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 56 / 31380
# e value: 3.1e-16
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 50 / 31380
# e value: 6.7e-13
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 50 / 31380
# e value: 6.7e-13
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 39 / 31380
# e value: 8.73e-07
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 38 / 31380
# e value: 3.14e-06
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 38 / 31380
# e value: 3.14e-06
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 40 / 31380
# e value: 1.13e-05
#
# suspicious assembly (1.00 query coverage, 0.93 ref coverage, 0 query dup, 0 ref dup, longest hit 28995): ERR2819915.coronaspades.NODE_1_length_29054_cluster_1_candidate_1_domains_31
# ****Alignment****
# aligns_to: AB354579.1
# aln_length: 28995 / 29054
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25150): SRR11826862.coronaspades.NODE_1_length_25150_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT520419.1
# aln_length: 25150 / 25150
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.94 ref coverage, 0 query dup, 0 ref dup, longest hit 27975): SRR11578300.coronaspades.NODE_1_length_28002_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: MT419814.1
# aln_length: 27975 / 28002
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 30 query dup, 272 ref dup, longest hit 28227): ERR1301828.coronaspades.NODE_1_length_28501_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: MH687944.1
# aln_length: 28227 / 28501
# e value: 0.0
# ****Alignment****
# aligns_to: MH687944.1
# aln_length: 108 / 28501
# e value: 3.49e-45
# ****Alignment****
# aligns_to: MH687944.1
# aln_length: 91 / 28501
# e value: 9.83e-36
# ****Alignment****
# aligns_to: MH687944.1
# aln_length: 77 / 28501
# e value: 4.67e-19
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 0 query dup, 21524 ref dup, longest hit 27778): ERR4164784.coronaspades.NODE_1_length_51507_cluster_1_candidate_1_domains_74
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 27778 / 51507
# e value: 0.0
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 20385 / 51507
# e value: 0.0
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 2603 / 51507
# e value: 0.0
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 457 / 51507
# e value: 0.0
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 196 / 51507
# e value: 4.61e-86
#
# suspicious assembly (0.94 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 30099): SRR1190504.coronaspades.NODE_1_length_31944_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 30099 / 31944
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.86 ref coverage, 6 query dup, 34 ref dup, longest hit 26030): SRR10357367.coronaspades.NODE_1_length_26054_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 26030 / 26054
# e value: 0.0
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 35 / 26054
# e value: 0.006
#
# suspicious assembly (1.00 query coverage, 0.90 ref coverage, 0 query dup, 0 ref dup, longest hit 26824): SRR11939545.coronaspades.NODE_1_length_26901_cluster_1_candidate_1_domains_34
# ****Alignment****
# aligns_to: MT293186.1
# aln_length: 26824 / 26901
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25229): SRR11597205.coronaspades.NODE_1_length_25229_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: MT270112.1
# aln_length: 25229 / 25229
# e value: 0.0
#
# suspicious assembly (0.93 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 30127): SRR10357373.coronaspades.NODE_1_length_32359_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 30127 / 32359
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.94 ref coverage, 113 query dup, 0 ref dup, longest hit 28020): SRR11777736.coronaspades.NODE_1_length_28045_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 28020 / 28045
# e value: 0.0
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 115 / 28045
# e value: 7.38e-47
#
# suspicious assembly (1.00 query coverage, 0.92 ref coverage, 0 query dup, 0 ref dup, longest hit 25470): SRR10742607.coronaspades.NODE_1_length_25497_cluster_1_candidate_1_domains_24
# ****Alignment****
# aligns_to: MN566147.1
# aln_length: 25470 / 25497
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25220): SRR11577861.coronaspades.NODE_1_length_25220_cluster_1_candidate_1_domains_35
# ****Alignment****
# aligns_to: MT628081.1
# aln_length: 25220 / 25220
# e value: 0.0
#
# suspicious assembly (0.93 query coverage, 0.99 ref coverage, 0 query dup, 134 ref dup, longest hit 29926): ERR963004.coronaspades.NODE_1_length_32325_cluster_1_candidate_1_domains_33
# ****Alignment****
# aligns_to: MK039552.1
# aln_length: 29926 / 32325
# e value: 0.0
# ****Alignment****
# aligns_to: MK039552.1
# aln_length: 135 / 32325
# e value: 1.8e-58
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 161 query dup, 258 ref dup, longest hit 29891): SRR11593364.coronaspades.NODE_1_length_29998_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT079852.1
# aln_length: 29891 / 29998
# e value: 0.0
# ****Alignment****
# aligns_to: MT079852.1
# aln_length: 94 / 29998
# e value: 1.04e-35
# ****Alignment****
# aligns_to: MT079852.1
# aln_length: 87 / 29998
# e value: 1.73e-33
# ****Alignment****
# aligns_to: MT079852.1
# aln_length: 80 / 29998
# e value: 1.35e-29
#
# suspicious assembly (1.00 query coverage, 0.84 ref coverage, 0 query dup, 0 ref dup, longest hit 25231): SRR11597202.coronaspades.NODE_1_length_25232_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: MT499184.1
# aln_length: 25231 / 25232
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.89 ref coverage, 183 query dup, 45 ref dup, longest hit 26501): SRR5871990.coronaspades.NODE_1_length_26501_cluster_1_candidate_1_domains_28
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 26501 / 26501
# e value: 0.0
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 46 / 26501
# e value: 9.47e-11
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 44 / 26501
# e value: 1.23e-09
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 34 / 26501
# e value: 0.000444
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 33 / 26501
# e value: 0.002
# ****Alignment****
# aligns_to: KY674943.1
# aln_length: 31 / 26501
# e value: 0.021
# suspicious assembly (0.95 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 30097): SRR1193924.coronaspades.NODE_1_length_31708_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 30097 / 31708
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.94 ref coverage, 113 query dup, 0 ref dup, longest hit 28016): SRR11777734.coronaspades.NODE_1_length_28026_cluster_1_candidate_1_domains_39
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 28016 / 28026
# e value: 0.0
# ****Alignment****
# aligns_to: MT079851.1
# aln_length: 115 / 28026
# e value: 7.37e-47
#
# suspicious assembly (0.91 query coverage, 1.00 ref coverage, 0 query dup, 0 ref dup, longest hit 30098): SRR1191668.coronaspades.NODE_1_length_33011_cluster_1_candidate_1_domains_36
# ****Alignment****
# aligns_to: JX869059.2
# aln_length: 30098 / 33011
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.92 ref coverage, 0 query dup, 0 ref dup, longest hit 25054): SRR5872115.coronaspades.NODE_1_length_25054_cluster_1_candidate_1_domains_32
# ****Alignment****
# aligns_to: KY967357.1
# aln_length: 25054 / 25054
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.95 ref coverage, 0 query dup, 0 ref dup, longest hit 28303): SRR11954068.coronaspades.NODE_1_length_28303_cluster_1_candidate_1_domains_38
# ****Alignment****
# aligns_to: MT520382.1
# aln_length: 28303 / 28303
# e value: 0.0
#
# suspicious assembly (1.00 query coverage, 0.90 ref coverage, 1508 query dup, 1125 ref dup, longest hit 26537): SRR2146117.coronaspades.NODE_1_length_26537_cluster_1_candidate_1_domains_29
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 26537 / 26537
# e value: 0.0
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 128 / 26537
# e value: 5.43e-43
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 119 / 26537
# e value: 5.47e-38
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 89 / 26537
# e value: 2.6e-21
# ****Alignment****
# aligns_to: AY597011.2
# aln_length: 33 / 26537
# e value: 0.002
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 5 query dup, 222 ref dup, longest hit 29867): SRR11140744.coronaspades.NODE_1_length_30087_cluster_1_candidate_1_domains_37
# ****Alignment****
# aligns_to: MT039887.1
# aln_length: 29867 / 30087
# e value: 0.0
# ****Alignment****
# aligns_to: MT039887.1
# aln_length: 122 / 30087
# e value: 6.07e-53
# ****Alignment****
# aligns_to: MT039887.1
# aln_length: 102 / 30087
# e value: 7.97e-42
#
# suspicious assembly (1.00 query coverage, 1.00 ref coverage, 394 query dup, 357 ref dup, longest hit 31234): ERR1301465.coronaspades.NODE_1_length_31358_cluster_1_candidate_1_domains_30
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 31234 / 31358
# e value: 0.0
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 145 / 31358
# e value: 6.56e-28
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 60 / 31358
# e value: 1.85e-18
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 50 / 31358
# e value: 6.7e-13
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 48 / 31358
# e value: 8.67e-12
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 38 / 31358
# e value: 3.14e-06
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 38 / 31358
# e value: 3.14e-06
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 34 / 31358
# e value: 0.000525
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 34 / 31358
# e value: 0.000525
# ****Alignment****
# aligns_to: MH687969.1
# aln_length: 34 / 31358
# e value: 0.000525

# %%
df.to_csv("catA-v3.blastn-QC.txt")
df
print(df.to_markdown())
#df[40:80]
# Out:
# |     | Assembly    |   AssemblyLen | Tech            | BestRef    |   BestRefLen |   LongestHit |   QueryCov |    RefCov |   QueryDup |   RefDup |   IDYmean |   IDYstdev |
# |----:|:------------|--------------:|:----------------|:-----------|-------------:|-------------:|-----------:|----------:|-----------:|---------:|----------:|-----------:|
# |   0 | ERR1301465  |         31358 | ILLUMINA        | MH687969.1 |        31352 |        31234 |   0.998246 | 0.998979  |        394 |      357 |   98.4641 | 4.33473    |
# |   1 | SRR11140744 |         30087 | ILLUMINA        | MT039887.1 |        29879 |        29867 |   0.999867 | 0.999565  |          5 |      222 |  100      | 0          |
# |   2 | SRR2146117  |         26537 | ILLUMINA        | AY597011.2 |        29926 |        26537 |   0.999962 | 0.899519  |       1508 |     1125 |   94.4134 | 2.47587    |
# |   3 | SRR11954068 |         28303 | ILLUMINA        | MT520382.1 |        29866 |        28303 |   0.999965 | 0.947633  |          0 |        0 |  100      | 0          |
# |   4 | SRR5872115  |         25054 | ILLUMINA        | KY967357.1 |        27242 |        25054 |   0.99996  | 0.919646  |          0 |        0 |  100      | 0          |
# |   5 | SRR1191668  |         33011 | ILLUMINA        | JX869059.2 |        30119 |        30098 |   0.911726 | 0.99927   |          0 |        0 |   99.987  | 0          |
# |   6 | SRR11777734 |         28026 | ILLUMINA        | MT079851.1 |        30018 |        28016 |   0.999608 | 0.937071  |        113 |        0 |   99.563  | 0.612354   |
# |   7 | SRR1193924  |         31708 | ILLUMINA        | JX869059.2 |        30119 |        30097 |   0.949161 | 0.999236  |          0 |        0 |   99.987  | 0          |
# |   8 | SRR5871990  |         26501 | ILLUMINA        | KY674943.1 |        29908 |        26501 |   0.999962 | 0.890665  |        183 |       45 |  100      | 0          |
# |   9 | SRR11597202 |         25232 | ILLUMINA        | MT499184.1 |        29893 |        25231 |   0.999921 | 0.84401   |          0 |        0 |   99.984  | 0          |
# |  10 | SRR11593364 |         29998 | ILLUMINA        | MT079852.1 |        29891 |        29891 |   0.999633 | 0.999967  |        161 |      258 |   99.7308 | 0.529869   |
# |  11 | ERR963004   |         32325 | ILLUMINA        | MK039552.1 |        30123 |        29926 |   0.929899 | 0.993427  |          0 |      134 |   99.623  | 0.514774   |
# |  12 | SRR11577861 |         25220 | ILLUMINA        | MT628081.1 |        29872 |        25220 |   0.99996  | 0.844235  |          0 |        0 |   99.996  | 0          |
# |  13 | SRR10742607 |         25497 | ILLUMINA        | MN566147.1 |        27631 |        25470 |   0.998863 | 0.921755  |          0 |        0 |   99.996  | 0          |
# |  14 | SRR11777736 |         28045 | ILLUMINA        | MT079851.1 |        30018 |        28020 |   0.999073 | 0.937204  |        113 |        0 |   99.5615 | 0.610233   |
# |  15 | SRR10357373 |         32359 | ILLUMINA        | JX869059.2 |        30119 |        30127 |   0.930869 | 0.999934  |          0 |        0 |   99.924  | 0          |
# |  16 | SRR11597205 |         25229 | ILLUMINA        | MT270112.1 |        29858 |        25229 |   0.99996  | 0.844933  |          0 |        0 |  100      | 0          |
# |  17 | SRR11939545 |         26901 | ILLUMINA        | MT293186.1 |        29865 |        26824 |   0.996989 | 0.898142  |          0 |        0 |   99.981  | 0          |
# |  18 | SRR10357367 |         26054 | ILLUMINA        | JX869059.2 |        30119 |        26030 |   0.999962 | 0.863907  |          6 |       34 |   98.531  | 1.96293    |
# |  19 | SRR1190504  |         31944 | ILLUMINA        | JX869059.2 |        30119 |        30099 |   0.942211 | 0.999303  |          0 |        0 |   99.987  | 0          |
# |  20 | ERR4164784  |         51507 | OXFORD_NANOPORE | MT499184.1 |        29893 |        27778 |   0.997068 | 0.99709   |          0 |    21524 |   99.0312 | 0.769228   |
# |  21 | ERR1301828  |         28501 | ILLUMINA        | MH687944.1 |        28219 |        28227 |   0.998281 | 0.999787  |         30 |      272 |   97.806  | 3.06186    |
# |  22 | SRR11578300 |         28002 | ILLUMINA        | MT419814.1 |        29743 |        27975 |   0.999    | 0.940524  |          0 |        0 |   99.996  | 0          |
# |  23 | SRR11826862 |         25150 | ILLUMINA        | MT520419.1 |        29833 |        25150 |   0.99996  | 0.842993  |          0 |        0 |   99.992  | 0          |
# |  24 | ERR2819915  |         29054 | ILLUMINA        | AB354579.1 |        31038 |        28995 |   0.9979   | 0.934113  |          0 |        0 |   99.672  | 0          |
# |  25 | ERR1301554  |         31380 | ILLUMINA        | MH687969.1 |        31352 |        31232 |   0.999267 | 0.998916  |        440 |      461 |   98.3753 | 4.12254    |
# |  26 | ERR4164855  |         31837 | OXFORD_NANOPORE | MT627426.1 |        29903 |        29520 |   0.999183 | 0.991941  |          4 |     2259 |   94.629  | 4.33393    |
# |  27 | SRR11771957 |         29877 | ILLUMINA        | MT482127.1 |        29901 |        19372 |   0.999699 | 0.998495  |          0 |       12 |  100      | 0          |
# |  28 | SRR1030058  |         32413 | ILLUMINA        | FJ882957.1 |        29720 |        29713 |   0.918119 | 0.999731  |          0 |       47 |   99.9965 | 0.00494975 |
# |  29 | SRR11772243 |         30990 | ILLUMINA        | MT450890.1 |        29865 |        22387 |   0.999839 | 0.998493  |          0 |     1165 |  100      | 0          |
# |  30 | ERR1424897  |         26516 | ILLUMINA        | KF686344.1 |        29695 |        26486 |   0.998831 | 0.899377  |        337 |      115 |   98.5174 | 0.889548   |
# |  31 | ERR4164797  |         30903 | OXFORD_NANOPORE | MT627422.1 |        29871 |        29808 |   0.999612 | 0.998761  |          0 |     1057 |   97.4345 | 3.51361    |
# |  32 | SRR6713714  |         28120 | ILLUMINA        | KU982977.1 |        28003 |        27982 |   0.999858 | 0.999214  |         62 |      201 |   95.1403 | 8.35232    |
# |  33 | ERR4182199  |         30660 | OXFORD_NANOPORE | MT627426.1 |        29903 |        21157 |   0.988193 | 0.993479  |          1 |      593 |   99.1502 | 1.12096    |
# |  34 | SRR6713776  |         28113 | ILLUMINA        | MK071627.1 |        28017 |        27979 |   0.999964 | 0.998608  |         63 |      201 |   95.145  | 8.35633    |
# |  35 | SRR1195790  |         32562 | ILLUMINA        | AY278741.1 |        29727 |        29702 |   0.912137 | 0.999125  |          0 |        0 |   99.997  | 0          |
# |  36 | ERR4181727  |         29749 | ILLUMINA        | MT428554.1 |        29903 |        15246 |   0.999966 | 0.991941  |          3 |       89 |   99.993  | 0          |
# |  37 | SRR6713741  |         28070 | ILLUMINA        | KJ645665.1 |        27998 |        27959 |   0.999964 | 0.998214  |        153 |      287 |   97.255  | 3.32014    |
# |  38 | SRR1030193  |         31374 | ILLUMINA        | FJ882957.1 |        29720 |        29720 |   0.947249 | 0.999966  |          0 |        0 |  100      | 0          |
# |  39 | SRR1195366  |         32879 | ILLUMINA        | AY278741.1 |        29727 |        29701 |   0.903312 | 0.999092  |          0 |        0 |   99.997  | 0          |
# |  40 | SRR11494499 |         25216 | ILLUMINA        | MT520215.1 |        29849 |        25216 |   0.99996  | 0.844752  |          0 |        0 |   99.992  | 0          |
# |  41 | SRR11578190 |         25234 | ILLUMINA        | MT470114.1 |        29903 |        25217 |   0.999287 | 0.84326   |          0 |        0 |  100      | 0          |
# |  42 | ERR4182183  |         27534 | OXFORD_NANOPORE | MT628262.1 |        29900 |        27293 |   0.999891 | 0.912676  |          0 |      251 |   97.045  | 4.10688    |
# |  43 | SRR11777735 |         28047 | ILLUMINA        | MT079851.1 |        30018 |        28016 |   0.998859 | 0.937071  |        113 |        0 |   99.563  | 0.612354   |
# |  44 | ERR3179284  |         29326 | ILLUMINA        | MH687972.1 |        31274 |        29326 |   0.999966 | 0.93768   |          0 |        0 |   99.997  | 0          |
# |  45 | SRR11578204 |         25216 | ILLUMINA        | MT628262.1 |        29900 |        25216 |   0.99996  | 0.843311  |          0 |        0 |   99.992  | 0          |
# |  46 | ERR4164796  |         30423 | OXFORD_NANOPORE | MT627426.1 |        29903 |        29820 |   0.994379 | 0.997191  |          1 |      436 |   98.022  | 1.71026    |
# |  47 | ERR4182432  |         30345 | OXFORD_NANOPORE | MT520546.1 |        29866 |        29838 |   0.997034 | 0.999029  |          0 |      457 |   95.6105 | 6.11718    |
# |  48 | SRR1193955  |         34150 | ILLUMINA        | JX869059.2 |        30119 |        30099 |   0.881347 | 0.999303  |          0 |        0 |   99.987  | 0          |
# |  49 | SRR11494528 |         25213 | ILLUMINA        | MT628262.1 |        29900 |        25213 |   0.99996  | 0.843211  |          0 |        0 |   99.992  | 0          |
# |  50 | ERR4182439  |         30298 | OXFORD_NANOPORE | MT535497.1 |        29850 |        29692 |   0.999967 | 0.99464   |          6 |      625 |   97.9965 | 2.42265    |
# |  51 | SRR9430938  |         31509 | CAPILLARY       | FJ425188.1 |        30995 |        30995 |   0.990162 | 0.999968  |          0 |      207 |   96.644  | 4.72772    |
# |  52 | ERR4181768  |         26418 | ILLUMINA        | MT325599.1 |        29882 |        26412 |   0.999735 | 0.88381   |          0 |        0 |   99.996  | 0          |
# |  53 | SRR6713767  |         28129 | ILLUMINA        | KF650373.1 |        28038 |        27988 |   0.999964 | 0.998181  |         62 |      207 |   95.074  | 8.37754    |
# |  54 | SRR11494457 |         25301 | ILLUMINA        | MT451603.1 |        29816 |        25206 |   0.998933 | 0.845351  |          2 |       71 |   99.998  | 0.00282843 |
# |  55 | ERR4182443  |         30141 | OXFORD_NANOPORE | MT627426.1 |        29903 |        24131 |   0.999967 | 0.998796  |          1 |      291 |   99.9065 | 0.0148492  |
# |  56 | SRR11859139 |         26806 | ILLUMINA        | MT614525.1 |        29782 |        26752 |   0.999963 | 0.899201  |          7 |       32 |   99.9945 | 0.00777817 |
# |  57 | SRR11550039 |         32184 | ILLUMINA        | FJ429166.1 |        29747 |        29709 |   0.923067 | 0.998689  |          0 |        0 |   99.997  | 0          |
# |  58 | SRR6713905  |         28123 | ILLUMINA        | KR265814.1 |        27991 |        27986 |   0.999893 | 0.999786  |         62 |      201 |   94.8763 | 8.78454    |
# |  59 | SRR10873977 |         26576 | ILLUMINA        | FJ376622.1 |        26552 |        14581 |   0.602386 | 0.602215  |         31 |       61 |   85.3877 | 8.58582    |
# |  60 | SRR11593359 |         30105 | ILLUMINA        | MT358641.1 |        29903 |        29861 |   0.9999   | 0.998562  |          0 |      242 |   99.999  | 0.00173205 |
# |  61 | SRR11494750 |         25220 | ILLUMINA        | MT628262.1 |        29900 |        25220 |   0.99996  | 0.843445  |          0 |        0 |   99.984  | 0          |
# |  62 | SRR11593358 |         25158 | ILLUMINA        | MT499184.1 |        29893 |        25036 |   0.999921 | 0.837487  |          0 |      121 |   99.994  | 0.00848528 |
# |  63 | SRR8369129  |         26534 | ILLUMINA        | DQ415911.1 |        29902 |        26528 |   0.999736 | 0.898602  |       1616 |     1306 |   95.1598 | 1.75425    |
# |  64 | SRR11140746 |         30137 | ILLUMINA        | MT039887.1 |        29879 |        29875 |   0.99917  | 0.999833  |          3 |      241 |  100      | 0          |
# |  65 | SRR8189298  |         25031 | ILLUMINA        | MK204411.1 |        28482 |        23419 |   0.998562 | 0.885507  |        331 |       90 |   94.6004 | 3.77351    |
# |  66 | SRR11857972 |         27110 | ILLUMINA        | MT628262.1 |        29900 |        27110 |   0.999963 | 0.906656  |          0 |        0 |  100      | 0          |
# |  67 | SRR1190467  |         32181 | ILLUMINA        | JX869059.2 |        30119 |        30101 |   0.936795 | 0.999369  |          0 |       47 |   99.9915 | 0.0120208  |
# |  68 | ERR4164805  |         26748 | OXFORD_NANOPORE | MT627422.1 |        29871 |        26582 |   0.999963 | 0.889425  |          0 |      178 |   99.344  | 0.634982   |
# |  69 | SRR1190466  |         33133 | ILLUMINA        | JX869059.2 |        30119 |        30098 |   0.908369 | 0.99927   |          0 |        0 |   99.987  | 0          |
# |  70 | ERR3013343  |         28355 | ILLUMINA        | LT898439.1 |        28030 |        28021 |   0.999612 | 0.999643  |          6 |      330 |   98.5505 | 1.67409    |
# |  71 | SRR6713902  |         28120 | ILLUMINA        | KR265814.1 |        27991 |        27986 |   0.999964 | 0.999786  |         63 |      201 |   94.4063 | 8.40116    |
# |  72 | SRR11140748 |         30108 | ILLUMINA        | MT039887.1 |        29879 |        29872 |   0.999934 | 0.999732  |         10 |      245 |   99.7333 | 0.46188    |
# |  73 | ERR3179763  |         28445 | ILLUMINA        | MH687966.1 |        28389 |        28378 |   0.997434 | 0.999613  |        304 |      303 |   97.2037 | 4.79498    |
# |  74 | SRR7239363  |         26091 | ILLUMINA        | MT025058.1 |        18944 |        18940 |   0.725882 | 0.999736  |          0 |        0 |  100      | 0          |
# |  75 | SRR6425313  |         26182 | ILLUMINA        | KY994645.1 |        30684 |        26181 |   0.999924 | 0.853181  |          0 |        0 |   99.939  | 0          |
# |  76 | SRR5872097  |         26518 | ILLUMINA        | KY674943.1 |        29908 |        26516 |   0.999887 | 0.891166  |        183 |       45 |  100      | 0          |
# |  77 | ERR4182427  |         30352 | OXFORD_NANOPORE | MT374105.1 |        29900 |        29863 |   0.999934 | 0.998696  |          1 |      502 |   98.2703 | 1.49561    |
# |  78 | SRR7623977  |         27342 | ILLUMINA        | KY364365.1 |        25422 |        17094 |   0.998793 | 0.999253  |          0 |     1906 |   99.79   | 0.0749533  |
# |  79 | SRR6713880  |         28097 | ILLUMINA        | KJ645704.1 |        27989 |        27964 |   0.999964 | 0.999071  |         69 |      206 |   94.7037 | 7.9971     |
# |  80 | ERR4181748  |         30021 | ILLUMINA        | MT079845.1 |        29955 |        29937 |   0.9999   | 0.999967  |        273 |      333 |   97.1092 | 3.34857    |
# |  81 | SRR11494725 |         25279 | ILLUMINA        | MT520521.1 |        29872 |        25217 |   0.99996  | 0.844403  |          3 |       58 |   99.996  | 0.00565685 |
# |  82 | SRR7623978  |         25432 | ILLUMINA        | KY364365.1 |        25422 |        15970 |   0.999961 | 0.997246  |          3 |       82 |   99.784  | 0.066468   |
# |  83 | SRR10873981 |         26508 | ILLUMINA        | FJ376622.1 |        26552 |        14582 |   0.602799 | 0.602215  |          0 |        0 |   83.2568 | 7.64135    |
# |  84 | ERR963027   |         28162 | ILLUMINA        | KJ813439.1 |        30123 |        28042 |   0.998225 | 0.930883  |          0 |       71 |   98.5985 | 1.94666    |
# |  85 | SRR11494532 |         25237 | ILLUMINA        | MT627426.1 |        29903 |        25217 |   0.999168 | 0.84326   |          0 |        0 |   99.996  | 0          |
# |  86 | SRR6713893  |         28113 | ILLUMINA        | KJ645691.1 |        27998 |        27982 |   0.999964 | 0.999393  |         66 |      201 |   95.1093 | 8.32581    |
# |  87 | SRR10915173 |         38489 | ILLUMINA        | KJ473822.1 |        30247 |        30256 |   0.786069 | 0.999967  |          0 |        0 |   98.38   | 0          |
# |  88 | SRR1192073  |         32442 | ILLUMINA        | JX869059.2 |        30119 |        30098 |   0.927717 | 0.99927   |          0 |        0 |   99.987  | 0          |
# |  89 | SRR11393704 |         30190 | ILLUMINA        | MT079851.1 |        30018 |        29884 |   0.998112 | 0.9993    |        115 |      252 |   99.3942 | 0.750928   |
# |  90 | SRR11621903 |         25821 | ILLUMINA        | MT520215.1 |        29849 |        25824 |   0.999961 | 0.865088  |          0 |        0 |   99.969  | 0          |
# |  91 | SRR6893872  |         25471 | ILLUMINA        | KY364365.1 |        25422 |        16001 |   0.999961 | 0.998781  |          3 |       82 |   99.781  | 0.0707107  |
# |  92 | SRR10829954 |         25269 | ILLUMINA        | KY420075.1 |        27967 |        25212 |   0.997151 | 0.901455  |          0 |        0 |   99.917  | 0          |
# |  93 | SRR11621817 |         29932 | ILLUMINA        | MT627434.1 |        29882 |        15955 |   0.999365 | 0.99585   |          8 |      163 |   99.9934 | 0.00920869 |
# |  94 | SRR11578301 |         27986 | ILLUMINA        | MT628262.1 |        29900 |        27986 |   0.999964 | 0.935953  |          0 |        0 |   99.986  | 0          |
# |  95 | SRR11826984 |         25450 | ILLUMINA        | MT520215.1 |        29849 |        25431 |   0.999214 | 0.851955  |          0 |        0 |   99.996  | 0          |
# |  96 | ERR1301491  |         28279 | ILLUMINA        | MH687944.1 |        28219 |        28067 |   0.999965 | 0.994578  |          5 |      217 |   99.6527 | 0.601599   |
# |  97 | ERR2738384  |         28445 | ILLUMINA        | MH687966.1 |        28389 |        28378 |   0.997434 | 0.999613  |        304 |      303 |   97.2037 | 4.79498    |
# |  98 | SRR11857956 |         26400 | ILLUMINA        | MT558673.1 |        29817 |        26400 |   0.999962 | 0.885367  |          0 |        0 |  100      | 0          |
# |  99 | SRR11622083 |         26308 | ILLUMINA        | MT627426.1 |        29903 |        26287 |   0.999164 | 0.878975  |          0 |        0 |   99.992  | 0          |
# | 100 | SRR11968904 |         28295 | BGISEQ          | MT568634.1 |        29861 |        28295 |   0.999965 | 0.947524  |          0 |        0 |  100      | 0          |
# | 101 | ERR4182437  |         30333 | OXFORD_NANOPORE | MT627422.1 |        29871 |        29809 |   0.999967 | 0.997891  |         14 |      546 |   97.0783 | 3.43648    |
# | 102 | SRR11597213 |         30136 | ILLUMINA        | MT499184.1 |        29893 |        29835 |   0.997379 | 0.998026  |          0 |      223 |   97.0965 | 4.10193    |
# | 103 | SRR1033849  |         25183 | ION_TORRENT     | EU418976.1 |        27636 |        25068 |   0.999563 | 0.904653  |          8 |      122 |   97.461  | 2.15809    |
# | 104 | SRR6713743  |         28153 | ILLUMINA        | KJ645704.1 |        27989 |        26015 |   0.998899 | 0.995069  |         40 |      313 |   98.7857 | 1.24156    |
# | 105 | SRR11939551 |         29914 | ILLUMINA        | MT628262.1 |        29900 |        29683 |   0.999933 | 0.992709  |          1 |      231 |  100      | 0          |
# | 106 | SRR11597148 |         25229 | ILLUMINA        | MT259230.1 |        29866 |        25229 |   0.99996  | 0.844706  |          0 |        0 |   99.996  | 0          |
# | 107 | ERR4182440  |         26986 | OXFORD_NANOPORE | MT627426.1 |        29903 |        26881 |   0.999963 | 0.89884   |          4 |      125 |   99.9535 | 0.0657609  |
# | 108 | SRR12003638 |         30104 | ILLUMINA        | MT535488.1 |        29903 |        29854 |   0.999801 | 0.998294  |         14 |      259 |   99.763  | 0.465374   |
# | 109 | SRR11916011 |         26805 | ILLUMINA        | MT627426.1 |        29903 |        26716 |   0.999217 | 0.893389  |          6 |       74 |   99.329  | 0.912168   |
# | 110 | ERR4164903  |         32040 | OXFORD_NANOPORE | MT520274.1 |        29749 |         1479 |   0.987797 | 0.0496823 |          0 |    30168 |   99.6514 | 1.10076    |
# | 111 | SRR11494506 |         25214 | ILLUMINA        | MT628262.1 |        29900 |        25210 |   0.999802 | 0.84311   |          0 |        0 |   99.996  | 0          |
# | 112 | SRR11140749 |         31251 | OXFORD_NANOPORE | MT121215.1 |        29945 |        29911 |   0.995648 | 0.998831  |          8 |     1206 |   97.5272 | 1.59119    |
# | 113 | SRR1191915  |         32532 | ILLUMINA        | JX869059.2 |        30119 |        30094 |   0.925028 | 0.999137  |          0 |        0 |   99.987  | 0          |

# %%
pip install dna_features_viewer
# Out:
# ...
#     100% |████████████████████████████████| 11.5MB 117kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 2.3MB 225kB/s ta 0:00:0111
# ...
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/ae/23/147de658aabbf968324551ea22c0c13a00284c4ef49a77002e91f79657b7/kiwisolver-1.2.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# ...
#     100% |████████████████████████████████| 13.4MB 86kB/s eta 0:00:011
# ...
#     100% |████████████████████████████████| 2.2MB 115kB/s ta 0:00:01
# ...

# %%
import seaborn as sns

# %%
""" just a test run """

from dna_features_viewer import GraphicFeature, GraphicRecord
features=[
    GraphicFeature(start=0, end=20, strand=+1, color="#ffd700",
                   label="Small feature"),
    GraphicFeature(start=20, end=500, strand=+1, color="#ffcccc",
                   label="Gene 1 with a very long name"),
    GraphicFeature(start=400, end=700, strand=-1, color="#cffccc",
                   label="Gene 2"),
    GraphicFeature(start=600, end=900, strand=+1, color="#ccccff",
                   label="Gene 3")
]
record = GraphicRecord(sequence_length=1000, features=features)
record.plot(figure_width=5)
# Out:
# (<AxesSubplot:>,
#  ({GF(Small feature, 0-20 (1)): 0,
#    GF(Gene 1 with a very long name, 20-500 (1)): 0,
#    GF(Gene 2, 400-700 (-1)): 1.0,
#    GF(Gene 3, 600-900 (1)): 0},
#   {GF(Gene 1 with a very long name, 20-500 (1)): {'feature_y': 0,
#     'annotation_y': 2.0},
#    GF(Small feature, 0-20 (1)): {'feature_y': 0, 'annotation_y': 1.0}}))

# %%
data = [(249,    654,    'bCoV_NSP1',        'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(771,    1494,   'CoV_NSP2_N',       'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(2178,   2679,   'CoV_NSP2_C',       'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(2862,   3375,   'bCoV_NSP3_N',      'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(3396,   3717,   'Macro',            'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(4275,   4704,   'bCoV_SUD_M',       'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(4716,   4908,   'bCoV_SUD_C',       'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(4914,   5871,   'CoV_peptidase',    'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(5988,   6282,   'bCoV_NAR',         'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(7005,   8469,   'CoV_NSP3_C',       'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(8586,   9648,   'CoV_NSP4_N',       'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(9720,   10008,  'CoV_NSP4_C',       'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(10098,  10971,  'Peptidase_C30',    'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(11802,  12051,  'CoV_NSP7',         'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(12051,  12642,  'CoV_NSP8',         'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(12645,  12984,  'CoV_NSP9',         'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(13008,  13377,  'CoV_NSP10',        'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(13443,  14499,  'CoV_RPol_N',       'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(14598,  16065,  'RdRP_1',           'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(17238,  17913,  'Viral_helicase1',  'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(18009,  19575,  'CoV_Methyltr_1',   'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(19581,  19764,  'CoV_NSP15_N',      'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(19791,  20082,  'CoV_NSP15_M',      'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(20154,  20613,  'CoV_NSP15_C',      'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(20622,  21510,  'CoV_Methyltr_2',   'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(21618,  22533,  'bCoV_S1_N',        'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(22566,  23100,  'bCoV_S1_RBD',      'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(23127,  23298,  'CoV_S1_C',         'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(23652,  25218,  'CoV_S2',           'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_2',  True),
(25353,  26175,  'bCoV_viroporin',   'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(26211,  26409,  'CoV_E',            'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(26526,  27129,  'CoV_M',            'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_3',  True),
(27162,  27345,  'bCoV_NS6',         'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(27399,  27516,  'bCoV_NS7A',        'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  False),
(27489,  27615,  'bCoV_NS7B',        'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(27627,  27981,  'bCoV_NS8',         'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(28017,  28308,  'bCoV_lipid_BD',    'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True),
(28128,  29151,  'CoV_nucleocap',    'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_3',  True),
(28467,  28677,  'bCoV_Orf14',       'SRR11939968.coronaspades.NODE_1_length_29527_cluster_1_candidate_1_domains_40_1',  True)]

# %%
""" just another test run, this time with real cov data  """

from dna_features_viewer import GraphicFeature, GraphicRecord
features=[]
#palette = sns.color_palette("hls", len(data))
palette = sns.color_palette("cubehelix", len(data))
cur_color = 0
dpalette = dict()

for i,e in enumerate(data):
    start, end, name, ctg, is_complete = e
    if name not in dpalette:
        dpalette[name] = palette[cur_color] # use next available color in palette
        cur_color = (cur_color + 1) % len(data)
    color = dpalette[name]
    features += [GraphicFeature(start=start, end=end, strand=+1, 
                                color = color,#)]
                                label=name)]
                # color="#ffd700")]
                   
record = GraphicRecord(sequence_length=30000, feature_level_height=0, features=features)
ax, _ = record.plot(figure_width=10)
ax.figure.savefig('sequence_and_translation.png', bbox_inches='tight')

# %%
""" run this cell to import structure data """

# import genome structure data
import marshal
marshal_filename = "../master_table/genome_structure.data.marshal"
gsdata = open(marshal_filename,'rb')
genome_structures = marshal.load(gsdata)
dgs = dict(genome_structures)
gsdata.close()

# %%
""" the real code lives here (run the cell above once too to import data) """

#import what to plot
# format: a text file with
#  [accession] [otu_name]
to_plot = set()
for line in open("../master_table/genome_structure.to_plot.txt"):
    to_plot.add(tuple(line.split()))
#print(to_plot)

from dna_features_viewer import GraphicFeature, GraphicRecord
#palette = sns.color_palette("hls", len(data))
palette = sns.color_palette("cubehelix", len(data))
cur_color = 0
dpalette = dict()

import matplotlib.pyplot as plt
nb_plots = len(to_plot)
fig, subplots  = plt.subplots(
    nb_plots, 1, figsize=(20, 3*nb_plots), sharex=True)
subplot_i = 0
for accession, why in sorted(list(to_plot),key = lambda x:x[1])[:nb_plots]:
    features = []
    for i,feature in enumerate(dgs[accession]):
        start, end, strand, name, ctg, is_complete = feature
        if name not in dpalette:
            dpalette[name] = palette[cur_color] # use next available color in palette
            cur_color = (cur_color + 1) % len(data)
        color = dpalette[name]
        features += [GraphicFeature(start=start, end=end, strand=int(strand+"1"), 
                                    color = color,#)]
                                    label=name)]
                    # color="#ffd700")]

    record = GraphicRecord(sequence_length=30000, feature_level_height=1, features=features)
    ax, _ = record.plot(ax=subplots[subplot_i], figure_width=30)
    ax.set_facecolor("white")
    ax.set_title('accession ' + accession + ' OTU: ' + why,loc='left')
    subplot_i += 1
fig.tight_layout(pad=5.)
fig.savefig('genome_structure.pdf', bbox_inches='tight')
